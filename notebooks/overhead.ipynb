# %%
from IPython.display import display, HTML
display(HTML(
    '<style>'
        '.jp-Notebook { padding-left: 0% !important; padding-right: 0% !important; width:100% !important; } '
    '</style>'
))

import pandas as pd
import numpy as np
import os

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib widget

matplotlib.style.use("bmh")
font = {'size': 13}
matplotlib.rc('font', **font)

# %load_ext autoreload
# %autoreload 2
    
import v0_2_0
# Out:
# <style>.jp-Notebook { padding-left: 0% !important; padding-right: 0% !important; width:100% !important; } </style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
PATH = "figures/overhead"
FIGSIZE=(3.2, 3)
os.makedirs(PATH, exist_ok=True)

# %%
overhead = {
    "redis": 29.79,
    "cass.": 16.19,
    "mysql": 8.32,
    "kafka": 7.99,
    "solr": 5.39,
}

# %%
plt.close("all")
plt.figure(figsize=FIGSIZE)
plt.bar(overhead.keys(), overhead.values())
plt.xticks(fontsize=10)
plt.ylabel("Overhead (%)")
plt.xlabel("Service")
plt.tight_layout()
plt.ylim([0, 100])
plt.savefig(f"{PATH}/overhead.pdf", bbox_inches='tight', pad_inches=0)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
